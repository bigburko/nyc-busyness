# %%
# Import geocoding function
# %run geocode_addresses.ipynb

# %%
# Process the data
df_with_coords = geocode_csv_addresses('rental.csv', method = 'geopy')
df_with_coords.to_csv('manhattan_listings_with_coordinates.csv', index=False)
# Out:
# Processing 1/213: 27 W 20th St
# Processing 2/213: 156 Fifth Ave
# Processing 3/213: 45 Broadway
# Processing 4/213: 420 Fifth Ave
# Processing 5/213: 451 Park Ave S
# Processing 6/213: 15 Maiden Ln
# Processing 7/213: 225 Broadway
# Processing 8/213: 131 Varick Street
# Processing 9/213: 242 W 30th Sr
# Processing 10/213: 157-163 W 25th St
# Processing 11/213: 150 W 30th St
# Processing 12/213: 134-142 W 37th St
# Processing 13/213: 25 Howard St
# Processing 14/213: 159 2nd Ave
# Processing 15/213: 137 Hudson St
# Processing 16/213: 251 W 71st St
# Processing 17/213: 475 Riverside Dr
# Processing 18/213: 1 Christopher St
# Processing 19/213: 165 - 167 Madison Ave
# Processing 20/213: 13-19 White St
# Processing 21/213: 1755 York Ave
# Processing 22/213: 156 E 109th St
# Processing 23/213: 155 Suffolk St
# Processing 24/213: 109 W 17th St
# Processing 25/213: 566 Amsterdam Ave
# Processing 26/213: 10 E 38th St
# Processing 27/213: 344 W 38th St
# Processing 28/213: 94 Bowery
# ...
